# %%
# titanic data  set for EDA

# %%
#import some libraries as per EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r'C:/Users/Asus/Downloads/archive (2)/train.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#2.Handle Missing Values

# %%
# Impute 'Age' with the median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Impute 'Embarked' with the mode
mode_embarked = df['Embarked'].mode()[0]
df['Embarked'].fillna(mode_embarked, inplace=True)

# Drop 'Cabin' due to excessive missing values
df.drop('Cabin', axis=1, inplace=True)

# Verify nulls are handled (excluding 'Cabin' which is dropped)
print("\n--- Nulls after Imputation ---")
print(df.isnull().sum())
# Out:
# --- Nulls after Imputation ---
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
# C:\Users\Asus\AppData\Local\Temp\ipykernel_22268\3136217482.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# ...

# %%
#3.Convert Categorical Features into Numerical (Encoding)

# %%
# 1. 'Sex': Use Label Encoding (or simple mapping)
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

# 2. 'Embarked': Use One-Hot Encoding
df = pd.get_dummies(df, columns=['Embarked'], drop_first=True) # drop_first avoids multicollinearity

print("\n--- Data after Encoding ---")
print(df[['Sex', 'Embarked_Q', 'Embarked_S']].head())
# Out:
# --- Data after Encoding ---
#    Sex  Embarked_Q  Embarked_S
# 0    0       False        True
# 1    1       False       False
# 2    1       False        True
# 3    1       False        True
# 4    0       False        True

# %%
#4.Normalize/Standardize Numerical Features

# %%
from sklearn.preprocessing import StandardScaler

# Select features for scaling
features_to_scale = ['Age', 'Fare']
scaler = StandardScaler()

# Fit and transform
df[features_to_scale] = scaler.fit_transform(df[features_to_scale])

print("\n--- Scaled Features (Age and Fare) ---")
print(df[['Age', 'Fare']].head())
# Out:
# --- Scaled Features (Age and Fare) ---
#         Age      Fare
# 0 -0.565736 -0.502445
# 1  0.663861  0.786845
# 2 -0.258337 -0.488854
# 3  0.433312  0.420730
# 4  0.433312 -0.486337

# %%
#5.Visualize Outliers and Remove Them

# %%
# Visualize 'Fare' outliers
plt.figure(figsize=(6, 4))
sns.boxplot(y=df['Fare'])
plt.title('Boxplot of Scaled Fare')
plt.show()


# Outlier Removal using IQR for 'Fare'
Q1 = df['Fare'].quantile(0.25)
Q3 = df['Fare'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove outliers
df_clean = df[(df['Fare'] >= lower_bound) & (df['Fare'] <= upper_bound)]

print(f"\nOriginal number of rows: {len(df)}")
print(f"Number of rows after outlier removal (Fare): {len(df_clean)}")
# Out:
# Original number of rows: 891
# Number of rows after outlier removal (Fare): 775

# %%
#Exploratory Data Analysis (EDA)

# %%
print("\n--- Summary Statistics of Clean Data ---")
print(df_clean.describe())
# Out:
# --- Summary Statistics of Clean Data ---
#        PassengerId    Survived     Pclass         Sex         Age       SibSp  \
# count   775.000000  775.000000  775.00000  775.000000  775.000000  775.000000
# mean    445.806452    0.339355    2.48000    0.314839   -0.047099    0.437419
# std     260.116285    0.473796    0.73439    0.464752    0.982304    0.899838
# min       1.000000    0.000000    1.00000    0.000000   -2.224156    0.000000
# 25%     213.500000    0.000000    2.00000    0.000000   -0.565736    0.000000
# 50%     450.000000    0.000000    3.00000    0.000000   -0.104637    0.000000
# 75%     670.500000    1.000000    3.00000    1.000000    0.356462    1.000000
# max     891.000000    1.000000    3.00000    1.000000    3.891554    5.000000
#
#             Parch        Fare
# count  775.000000  775.000000
# mean     0.340645   -0.289579
# std      0.785914    0.273391
# min      0.000000   -0.648422
# 25%      0.000000   -0.489442
# 50%      0.000000   -0.386671
# ...

# %%
#Create Histograms and Boxplots for Numeric Features

# %%
# Set style
sns.set_style("whitegrid")

# Histogram for Pclass (as a pseudo-numeric discrete feature)
plt.figure(figsize=(6, 4))
sns.histplot(df_clean['Pclass'], bins=3, kde=False, discrete=True)
plt.title('Distribution of Passenger Class (Pclass)')
plt.show()


# Histogram for Scaled Age
plt.figure(figsize=(6, 4))
sns.histplot(df_clean['Age'], kde=True)
plt.title('Distribution of Scaled Age')
plt.show()

# %%
# Use Pairplot/Correlation Matrix for Feature Relationships
# A correlation matrix is best for a quick overview of linear relationships.

# %%
# Calculate the correlation matrix
correlation_matrix = df_clean.corr(numeric_only=True)

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Features')
plt.show()

# %%
# 4. & 5. Identify Patterns and Make Feature-Level Inferences (Survival Focus)
# Let's visualize the relationship between key features and the target variable, Survived.

# %%
# Survival Rate by Pclass
plt.figure(figsize=(6, 4))
sns.barplot(x='Pclass', y='Survived', data=df_clean)
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.show()
